# %%
from glob import iglob
from datetime import datetime
from itertools import chain, repeat

import numpy as np
import pandas as pd
from cytoolz import compose, reduce
from h5py import File
from dask import delayed, compute
from dask.bag import from_sequence
from dask.diagnostics import ProgressBar
import matplotlib.pyplot as plt

# %%
def is_available(filename):
    try:
        with File(filename, 'r'):
            pass
        return True
    except Exception:
        return False


def read_scala(filename, tag_offset = None):
    if tag_offset is None:
        where = slice(None)
    else:
        where = slice(tag_offset, None)
    with File(filename, 'r') as f:
        try:
            for tag, iom, img, dt in zip(
                f['/bunches'][where],
                f['/photon_diagnostics/FEL01/I0_monitor/iom_sh_a_pc'][where],
                f['/vmi/andor'],
                f['/user_laser/delay_line/position'][where],
            ):
                yield {
                    'tag': tag,
                    'iom_intensity_pc': iom,
                    'img_intensity': img.sum(),
                    'delay_float': dt,
                }
        except KeyError:
            return


def read_img(filename, tag_offset = None):
    if tag_offset is None:
        where = slice(None)
    else:
        where = slice(tag_offset, None)
    with File(filename, 'r') as f:
        try:
            for tag, img in zip(
                f['/bunches'][where],
                f['/vmi/andor'],
            ):
                yield {
                    'tag': tag,
                    'img': img.astype('double'),
                }
        except KeyError:
            return

# %%
run = 219
tag_offset = 0  # 0 or 1
filenames = sorted(fn for fn in set(iglob(f"/data/*/Run_{run:03d}/rawdata/*.h5")) if is_available(fn))
filenames
# Out:
# ['/data/Step501N2/Run_219/rawdata/Run_219_487233077.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487233177.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487233277.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487233377.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487233477.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487233577.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487233677.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487233777.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487233877.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487233977.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487234077.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487234177.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487234277.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487234377.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487234477.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487234577.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487234677.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487234777.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487234877.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487234977.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487235273.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487235373.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487235473.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487235573.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487235673.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487235773.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487235873.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487235973.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487236073.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487236173.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487236273.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487236373.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487236473.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487236573.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487236673.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487236773.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487236873.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487236973.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487237073.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487237173.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487237460.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487237560.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487237660.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487237760.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487237860.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487237960.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487238060.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487238160.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487238260.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487238360.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487238460.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487238560.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487238660.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487238760.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487238860.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487238960.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487239060.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487239160.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487239260.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487239360.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487239672.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487239772.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487239872.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487239972.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487240072.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487240172.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487240272.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487240372.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487240472.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487240572.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487240672.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487240772.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487240872.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487240972.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487241072.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487241172.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487241272.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487241372.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487241472.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487241572.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487241901.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487242001.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487242101.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487242201.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487242301.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487242401.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487242501.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487242601.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487242701.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487242801.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487242901.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487243001.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487243101.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487243201.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487243301.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487243401.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487243501.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487243601.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487243701.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487243801.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487244115.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487244215.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487244315.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487244415.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487244515.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487244615.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487244715.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487244815.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487244915.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487245015.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487245115.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487245215.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487245315.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487245415.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487245515.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487245615.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487245715.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487245815.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487245915.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487246015.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487246246.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487246346.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487246446.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487246546.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487246646.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487246746.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487246846.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487246946.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487247046.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487247146.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487247246.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487247346.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487247446.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487247546.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487247646.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487247746.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487247846.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487247946.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487248046.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487248146.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487248397.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487248497.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487248597.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487248697.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487248797.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487248897.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487248997.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487249097.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487249197.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487249297.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487249397.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487249497.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487249597.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487249697.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487249797.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487249897.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487249997.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487250097.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487250197.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487250297.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487250552.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487250652.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487250752.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487250852.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487250952.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487251052.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487251152.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487251252.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487251352.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487251452.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487251552.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487251652.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487251752.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487251852.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487251952.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487252052.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487252152.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487252252.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487252352.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487252452.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487252696.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487252796.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487252896.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487252996.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487253096.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487253196.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487253296.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487253396.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487253496.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487253596.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487253696.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487253796.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487253896.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487253996.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487254096.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487254196.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487254296.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487254396.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487254496.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487254596.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487254839.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487254939.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487255039.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487255139.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487255239.h5',
#  '/data/Step501N2/Run_219/rawdata/Run_219_487
    bins = (centers[1:] + centers[:-1]) / 2
    return centers.item(np.digitize(d, bins=bins))


df["delay"] = df["delay_float"].apply(binit)
df["delay"].unique()
# Out:
# array([-6.61, -6.58, -6.55, -6.52, -6.49, -6.46, -6.43, -6.4 , -6.37,
#        -6.34, -6.31, -6.28, -6.25, -6.22, -6.19, -6.16, -6.13, -6.1 ])

# %%
plt.hist(df["iom_intensity_pc"], bins=200)
plt.xlabel("IOM (pC)")
plt.ylabel("Counts")
plt.grid(True)
plt.show()

# %%
bg_period, bg_mod = 3, 0  # /Background_Period
df["is_bg"] = df["tag"] % bg_period == bg_mod
plt.figure()
plt.subplot(121)
where = df["is_bg"]
plt.hist2d(df[where]["iom_intensity_pc"],
           df[where]["img_intensity"], bins=[100, 100], cmap="Greys")
plt.title("Background")
plt.xlabel("IOM (pC)")
plt.ylabel("VMI intensity")
plt.xlim(0, 15)
plt.ylim(1.6e8, 3e8)
plt.grid(True)

plt.subplot(122)
where = ~df["is_bg"]
plt.hist2d(df[where]["iom_intensity_pc"],
           df[where]["img_intensity"], bins=[100, 100], cmap="Greys")
plt.title("Singal")
plt.xlabel("IOM (pC)")
plt.ylabel("VMI intensity")
plt.xlim(0, 15)
plt.ylim(1.6e8, 3e8)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
ddf = (
    from_sequence(filenames)
    .map(read_img, tag_offset=tag_offset)
    .flatten()
    .to_dataframe()
    .merge(df, on="tag")
)
where = (
    10 < ddf['iom_intensity_pc']  # Change me!
)

with ProgressBar():
    summed = compute(
        *[
            {
                'is_bg': bg, 'delay': dt,
                'count': delayed(ddf[where & (ddf['is_bg'] == bg) & (ddf['delay'] == dt)]['img'].to_bag().count()),
                'summed': delayed(ddf[where & (ddf['is_bg'] == bg) & (ddf['delay'] == dt)]['img'].to_bag().sum()),
            }
            for bg in [True, False] for dt in df["delay"].unique()
        ],
    )

summed = pd.DataFrame(list(summed)).set_index(['delay', 'is_bg'])
summed
# Out:
# [########################################] | 100% Completed | 11min 52.3s
#              count                                             summed
# delay is_bg
# -6.61 True     665  [[71275.0, 70722.0, 70790.0, 71966.0, 72128.0,...
# -6.58 True     665  [[71383.0, 71153.0, 71020.0, 71857.0, 72331.0,...
# -6.55 True    1332  [[143179.0, 142003.0, 141987.0, 143948.0, 1446...
# -6.52 True     665  [[71255.0, 71533.0, 70860.0, 71848.0, 71978.0,...
# -6.49 True    1227  [[131153.0, 130860.0, 130486.0, 132448.0, 1330...
# -6.46 True     658  [[70401.0, 69947.0, 69949.0, 71017.0, 71348.0,...
# -6.43 True    1321  [[141749.0, 141130.0, 140884.0, 142923.0, 1433...
# -6.40 True     601  [[64419.0, 64296.0, 64044.0, 65028.0, 65228.0,...
# -6.37 True    1304  [[139977.0, 139018.0, 139109.0, 140880.0, 1414...
# -6.34 True     666  [[71577.0, 71024.0, 70991.0, 72073.0, 72347.0,...
# -6.31 True    1311  [[140816.0, 140567.0, 140118.0, 141831.0, 1425...
# -6.28 True     666  [[71420.0, 71133.0, 70906.0, 71872.0, 72118.0,...
# -6.25 True    1307  [[140278.0, 140151.0, 139132.0, 141113.0, 1422...
# -6.22 True     666  [[71339.0, 70942.0, 71089.0, 71794.0, 72344.0,...
# -6.19 True    1332  [[143164.0, 142340.0, 142226.0, 144240.0, 1446...
# -6.16 True     667  [[71638.0, 71491.0, 71200.0, 71950.0, 72460.0,...
# -6.13 True    1326  [[142411.0, 141880.0, 141232.0, 143176.0, 1443...
# -6.10 True     667  [[71553.0, 71176.0, 71166.0, 72100.0, 72626.0,...
# -6.61 False   1328  [[148582.0, 148364.0, 147006.0, 149226.0, 1500...
# -6.58 False   1328  [[148601.0, 148340.0, 147160.0, 149264.0, 1499...
# -6.55 False   2664  [[297564.0, 296718.0, 294292.0, 299101.0, 3002...
# -6.52 False   1329  [[148617.0, 148116.0, 147089.0, 149267.0, 1500...
# -6.49 False   2464  [[274628.0, 275419.0, 272012.0, 276230.0, 2773...
# -6.46 False   1316  [[146818.0, 147118.0, 145636.0, 147812.0, 1486...
# -6.43 False   2650  [[295812.0, 296323.0, 293793.0, 297885.0, 2998...
# -6.40 False   1203  [[134194.0, 134420.0, 133115.0, 135062.0, 1360...
# -6.37 False   2610  [[291018.0, 291587.0, 288417.0, 293094.0, 2947...
# -6.34 False   1327  [[148218.0, 148314.0, 146729.0, 149039.0, 1494...
# -6.31 False   2622  [[292097.0, 294163.0, 289897.0, 294483.0, 2958...
# -6.28 False   1328  [[147329.0, 147469.0, 146112.0, 148677.0, 1491...
# -6.25 False   2621  [[290944.0, 291783.0, 288572.0, 293063.0, 2940...
# -6.22 False   1329  [[147429.0, 148251.0, 146406.0, 148575.0, 1488...
# -6.19 False   2657  [[295420.0, 295778.0, 292357.0, 297197.0, 2988...
# -6.16 False   1332  [[148038.0, 148431.0, 146831.0, 148618.0, 1494...
# -6.13 False   2653  [[295396.0, 294712.0, 292355.0, 297127.0, 2980...
# -6.10 False   1330  [[147954.0, 147724.0, 146729.0, 148987.0, 1495...

# %%
avg = {
    k: {'delay': k,
        'bg_n': summed.loc[(k, True), 'count'],
        'bg_img': summed.loc[(k, True), 'summed'] / summed.loc[(k, True), 'count'],
        'sg_n': summed.loc[(k, False), 'count'],
        'sg_img': summed.loc[(k, False), 'summed'] / summed.loc[(k, False), 'count'],
        'df_n': summed.loc[(k, False), 'count'],
        'df_img': (summed.loc[(k, False), 'summed'] / summed.loc[(k, False), 'count']
                   - summed.loc[(k, True), 'summed'] / summed.loc[(k, True), 'count'])}
    for k in df["delay"].unique()
} 

for k, d in avg.items():
    plt.figure(figsize=(15, 5))
    plt.subplot(131)
    plt.title("Background")
    plt.pcolormesh(d['bg_img'], cmap="Greys")
    plt.clim(0, None)
    plt.axis('equal')
    plt.subplot(132)
    plt.title("Signal")
    plt.pcolormesh(d['sg_img'], cmap="Greys")
    plt.clim(0, None)
    plt.axis('equal')
    plt.subplot(133)
    plt.title("Diff")
    plt.pcolormesh(d['df_img'], cmap="Greys")
    plt.clim(0, None)
    plt.axis('equal')
    plt.tight_layout()
    plt.show()
    break

plt.figure()
plt.plot([k for k in avg], [d['df_img'].sum() for d in avg.values()], 'o-')
plt.grid(True)
plt.show()

# %%
# print(filenames)
writein = f"/data/Step501N2/Run_{run:03d}/work"

for k, d in avg.items():
    with File(f"{writein}/reduced_dt={k:.3f}.h5", "w") as f:
        f['delay'] = d['delay']
        f['bg_n'] = d['bg_n']
        f['bg_img'] = d['bg_img']
        f['sg_n'] = d['sg_n']
        f['sg_img'] = d['sg_img']
        f['df_n'] = d['df_n']
        f['df_img'] = d['df_img']
