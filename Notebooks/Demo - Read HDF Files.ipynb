# %%
import glob

import h5py
import matplotlib.pyplot as plt

# %matplotlib notebook

# %%
globbed = glob.glob("/data/Data/Run_187/rawdata/Run_*_[1-9]*.h5")
globbed
# Out:
# ['/data/Data/Run_187/rawdata/Run_187_484727571.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484727671.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484727771.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484727871.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484727971.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484728071.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484728171.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484728271.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484728371.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484728471.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484728571.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484728671.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484728771.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484728871.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484728971.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484729071.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484729171.h5',
#  '/data/Data/Run_187/rawdata/Run_187_484729271.h5',
# ...

# %%
filename = globbed[0]
file = h5py.File(filename, "r")
file
# Out:
# <HDF5 file "Run_187_484727571.h5" (mode r)>

# %%
arr = file["/digitizer/channel1"][...].sum(axis=0)
plt.plot(arr)
# Out:
# <img src="data:image/png;base64,..." width="640">
